# %% [markdown]
# # Toronto Dwellings Analysis
#
# In this assignment, you will perform fundamental analysis for the Toronto dwellings market to allow potential real estate investors to choose rental investment properties.

# %%
# imports
import plotly.express as px
import matplotlib.pyplot as plt
import panel as pn
import pandas as pd
import os
from pathlib import Path
from dotenv import load_dotenv

# %%
# Set up Panel Plotly extension
pn.extension('plotly')

# %%
# Import hvplot.pandas after pn.extension
import hvplot.pandas

# %%
# Read the Mapbox API key
load_dotenv()
map_box_api = os.getenv("mapbox")

# %% [markdown]
# ## Load Data

# %%
# Read the census data into a Pandas DataFrame
file_path = Path("Data/toronto_neighbourhoods_census_data.csv")
to_data = pd.read_csv(file_path, index_col="year")
to_data.head()
# Out:
#                      neighbourhood  single_detached_house  \
# year
# 2001               Agincourt North                   3715
# 2001  Agincourt South-Malvern West                   3250
# 2001                     Alderwood                   3175
# 2001                         Annex                   1060
# 2001             Banbury-Don Mills                   3615
#
#       apartment_five_storeys_plus  movable_dwelling  semi_detached_house  \
# year
# 2001                         1480                 0                 1055
# 2001                         1835                 0                  545
# 2001                          315                 0                  470
# 2001                         6090                 5                 1980
# 2001                         4465                 0                  240
#
#       row_house  duplex  apartment_five_storeys_less  other_house  \
# year
# 2001       1295     195                          185            5
# ...

# %% [markdown]
# - - -

# %% [markdown]
# ## Dwelling Types Per Year
#
# In this section, you will calculate the number of dwelling types per year. Visualize the results using bar charts and the Pandas plot function.
#
# **Hint:** Use the Pandas `groupby` function.
#
# **Optional challenge:** Plot each bar chart in a different color.

# %%
# Calculate the sum number of dwelling types units per year (hint: use groupby)
to_data_per_year = to_data.groupby('year').sum().drop(columns=["average_house_value","shelter_costs_owned", "shelter_costs_rented"])
to_data_per_year
# Out:
#       single_detached_house  apartment_five_storeys_plus  movable_dwelling  \
# year
# 2001                 300930                       355015                75
# 2006                 266860                       379400               165
# 2011                 274940                       429220               100
# 2016                 269680                       493270                95
#
#       semi_detached_house  row_house  duplex  apartment_five_storeys_less  \
# year
# 2001                90995      52355   23785                       116900
# 2006                69430      54690   44095                       162850
# 2011                72480      60355   44750                       163895
# 2016                71200      61565   48585                       165575
#
#       other_house
# year
# 2001         3040
# 2006         1335
# 2011         2165
# 2016         2845

# %%
# Save the dataframe as a csv file
to_data_per_year.to_csv("Data/total_number_of_dwelling_per_year.csv")

# %%
# Extract data for each year
year_2001 = pd.DataFrame(to_data_per_year.iloc[0,:])
year_2001.columns=['number_of_dwelling']

year_2006 = pd.DataFrame(to_data_per_year.iloc[1,:])
year_2006.columns=['number_of_dwelling']

year_2011 = pd.DataFrame(to_data_per_year.iloc[2,:])
year_2011.columns=['number_of_dwelling']

year_2016 = pd.DataFrame(to_data_per_year.iloc[3,:])
year_2016.columns=['number_of_dwelling']

# %%
# Helper create_bar_chart function
def create_bar_chart(data, title, xlabel, ylabel, color):
    plt.bar(x=data.index, height=data.number_of_dwelling, color=color, width = 0.6)
    plt.title(title,fontweight='bold')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(rotation=90)

# %%
# Create a bar chart per year to show the number of dwelling types
# Bar chart for 2001
bar_chart_2001 = create_bar_chart(year_2001,'Dwelling Types in Toronto in 2001', '2001', 'Dwelling Type Units', 'red')

# %%
# Bar chart for 2006
bar_chart_2006 = create_bar_chart(year_2006,'Dwelling Types in Toronto in 2006', '2006', 'Dwelling Type Units', "blue")

# %%
# Bar chart for 2011
bar_chart_2011 = create_bar_chart(year_2011,'Dwelling Types in Toronto in 2011', '2011', 'Dwelling Type Units', 'orange')

# %%
# Bar chart for 2016
bar_chart_2016 = create_bar_chart(year_2016,'Dwelling Types in Toronto in 2016', '2016', 'Dwelling Type Units', 'fuchsia')

# %% [markdown]
# - - -

# %% [markdown]
# ## Average Monthly Shelter Costs in Toronto Per Year
#
# In this section, you will calculate the average monthly shelter costs for owned and rented dwellings and the average house value for each year. Plot the results as a line chart.
#
# **Optional challenge:** Plot each line chart in a different color.

# %%
# Calculate the average monthly shelter costs for owned and rented dwellings
average_costs = to_data[["shelter_costs_owned", 'shelter_costs_rented']].groupby("year").mean()
average_costs.head()
# Out:
#       shelter_costs_owned  shelter_costs_rented
# year
# 2001           846.878571           1085.935714
# 2006          1316.800000            925.414286
# 2011          1448.214286           1019.792857
# 2016          1761.314286           1256.321429

# %%
# Helper create_line_chart function
def create_line_chart(data, title, xlabel, ylabel, color):
    plt.plot(data, color=color)
    plt.title(title,fontweight='bold')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

# %%
# Create two line charts, one to plot the monthly shelter costs for owned dwelleing and other for rented dwellings per year

# Line chart for owned dwellings
line_chart_owned = create_line_chart(average_costs["shelter_costs_owned"],"Average Monthly Shelter Cost for Owned Dwelling in Toronto", "Year", "Avg Monthly Shelter Costs", "blue")

# %%
# Line chart for rented dwellings
line_chart_rented = create_line_chart(average_costs["shelter_costs_rented"],"Average Monthly Shelter Cost for Rented Dwelling in Toronto", "Year", "Avg Monthly Shelter Costs", "orange")

# %% [markdown]
# ## Average House Value per Year
#
# In this section, you want to determine the average house value per year. An investor may want to understand better the sales price of the rental property over time. For example, a customer will want to know if they should expect an increase or decrease in the property value over time so they can determine how long to hold the rental property. You will visualize the `average_house_value` per year as a bar chart.

# %%
# Calculate the average house value per year
average_house_value = to_data[["average_house_value"]].groupby("year").mean()
average_house_value
# Out:
#       average_house_value
# year
# 2001        289882.885714
# 2006        424059.664286
# 2011        530424.721429
# 2016        664068.328571

# %%
# Plot the average house value per year as a line chart
line_chart_house_value = create_line_chart(average_house_value,"Average House Value in Toronto", "Year", "Avg House Value", "blue")

# %% [markdown]
# - - -

# %% [markdown]
# ## Average House Value by Neighbourhood
#
# In this section, you will use `hvplot` to create an interactive visualization of the average house value with a dropdown selector for the neighbourhood.
#
# **Hint:** It will be easier to create a new DataFrame from grouping the data and calculating the mean house values for each year and neighbourhood.

# %%
# Create a new DataFrame for average house value
df_house_values = pd.DataFrame(to_data,columns=["neighbourhood", "average_house_value"]).reset_index()
df_avg_house_value = pd.DataFrame(df_house_values,columns=["neighbourhood", "average_house_value"]).set_index("neighbourhood").groupby("neighbourhood").
df_house_values.head(10)
# Out:
#    year                 neighbourhood  average_house_value
# 0  2001               Agincourt North               200388
# 1  2001  Agincourt South-Malvern West               203047
# 2  2001                     Alderwood               259998
# 3  2001                         Annex               453850
# 4  2001             Banbury-Don Mills               371864
# 5  2001                Bathurst Manor               304749
# 6  2001           Bay Street Corridor               257404
# 7  2001               Bayview Village               327644
# 8  2001         Bayview Woods-Steeles               343535
# 9  2001          Bedford Park-Nortown               565304

# %%
# Use hvplot to create an interactive line chart of the average house value per neighbourhood
# The plot should have a dropdown selector for the neighbourhood
plot_avg_house_value = df_house_values.hvplot(y="average_house_value", x="year", groupby="neighbourhood",yformatter="%.0f", ylabel="Avg. House Value")
plot_avg_house_value
# Out:
# :DynamicMap   [neighbourhood]
#    :Curve   [year]   (average_house_value)

# %% [markdown]
# ## Number of Dwelling Types per Year
#
# In this section, you will use `hvplot` to create an interactive visualization of the average number of dwelling types per year with a dropdown selector for the neighbourhood.

# %%
# Fetch the data of all dwelling types per year
df_number_of_dwelling = pd.DataFrame(to_data).drop(columns=["average_house_value","shelter_costs_owned", "shelter_costs_rented"]).reset_index()
df_number_of_dwelling.head(10)
# Out:
#    year                 neighbourhood  single_detached_house  \
# 0  2001               Agincourt North                   3715
# 1  2001  Agincourt South-Malvern West                   3250
# 2  2001                     Alderwood                   3175
# 3  2001                         Annex                   1060
# 4  2001             Banbury-Don Mills                   3615
# 5  2001                Bathurst Manor                   2405
# 6  2001           Bay Street Corridor                     10
# 7  2001               Bayview Village                   2170
# 8  2001         Bayview Woods-Steeles                   1650
# 9  2001          Bedford Park-Nortown                   4985
#
#    apartment_five_storeys_plus  movable_dwelling  semi_detached_house  \
# 0                         1480                 0                 1055
# 1                         1835                 0                  545
# 2                          315                 0                  470
# ...

# %%
# Use hvplot to create an interactive bar chart of the number of dwelling types per neighbourhood
# The plot should have a dropdown selector for the neighbourhood
plot_number_of_dwelling = df_number_of_dwelling.hvplot.bar(x="year", groupby="neighbourhood",yformatter="%.0f", xlabel="Year", ylabel="Dwelling Type Units", rot=90, height=500)
plot_number_of_dwelling
# Out:
# :DynamicMap   [neighbourhood]
#    :Bars   [year,Variable]   (value)

# %% [markdown]
# - - -

# %% [markdown]
# ## The Top 10 Most Expensive Neighbourhoods
#
# In this section, you will need to calculate the house value for each neighbourhood and then sort the values to obtain the top 10 most expensive neighbourhoods on average. Plot the results as a bar chart.

# %%
# Getting the data from the top 10 expensive neighbourhoods
df_avg_house_value = pd.DataFrame(df_house_values,columns=["neighbourhood", "average_house_value"]).set_index("neighbourhood").groupby("neighbourhood").mean()
df_avg_house_value_top10 = df_avg_house_value.sort_values(by="average_house_value", ascending=False).nlargest(10, "average_house_value")
df_avg_house_value_top10
# Out:
#                                    average_house_value
# neighbourhood
# Bridle Path-Sunnybrook-York Mills           1526485.75
# Forest Hill South                           1195992.50
# Lawrence Park South                         1094027.75
# Rosedale-Moore Park                         1093640.00
# St.Andrew-Windfields                         999107.00
# Casa Loma                                    981064.25
# Bedford Park-Nortown                         930415.25
# Forest Hill North                            851680.50
# Kingsway South                               843234.25
# Yonge-St.Clair                               813220.25

# %%
# Plotting the data from the top 10 expensive neighbourhoods
plot_avg_house_value_top10 = df_avg_house_value_top10.hvplot.bar(x="neighbourhood", y="average_house_value",yformatter="%.0f", xlabel="Neighbourhood", ylabel="Avg. House Value", rot=90, height=500, title="Top 10 Expensive Neighbourhoods in Toronto", color="mediumblue")
plot_avg_house_value_top10
# Out:
# :Bars   [neighbourhood]   (average_house_value)

# %% [markdown]
# - - -

# %% [markdown]
# ## Neighbourhood Map
#
# In this section, you will read in neighbourhoods location data and build an interactive map with the average house value per neighbourhood. Use a `scatter_mapbox` from Plotly express to create the visualization. Remember, you will need your Mapbox API key for this.

# %% [markdown]
# ### Load Location Data

# %%
# Load neighbourhoods coordinates data
file_path = Path("Data/toronto_neighbourhoods_coordinates.csv")
df_neighbourhood_locations = pd.read_csv(file_path)
df_neighbourhood_locations = df_neighbourhood_locations.set_index("neighbourhood")
df_neighbourhood_locations.head()
# Out:
#                                     lat        lon
# neighbourhood
# Agincourt North               43.805441 -79.266712
# Agincourt South-Malvern West  43.788658 -79.265612
# Alderwood                     43.604937 -79.541611
# Annex                         43.671585 -79.404001
# Banbury-Don Mills             43.737657 -79.349718

# %% [markdown]
# ### Data Preparation
#
# You will need to join the location data with the mean values per neighbourhood.
#
# 1. Calculate the mean values for each neighbourhood.
#
# 2. Join the average values with the neighbourhood locations.

# %%
# Calculate the mean values for each neighborhood
# Comments: Mean values have been calculated above (df_avg_house_value)

# Join the average values with the neighbourhood locations
df_joint = pd.concat([df_neighbourhood_locations, df_avg_house_value],join="inner",axis=1).reset_index()
df_joint.head()
# Out:
#                   neighbourhood        lat        lon  average_house_value
# 0               Agincourt North  43.805441 -79.266712             329811.5
# 1  Agincourt South-Malvern West  43.788658 -79.265612             334189.0
# 2                     Alderwood  43.604937 -79.541611             427922.5
# 3                         Annex  43.671585 -79.404001             746977.0
# 4             Banbury-Don Mills  43.737657 -79.349718             612039.0

# %%
# Checking for null
df_joint.isnull().sum()
# Out:
# neighbourhood          0
# lat                    0
# lon                    0
# average_house_value    0
# dtype: int64

# %%
# Checking for duplicates
df_joint.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Mapbox Visualization
#
# Plot the average values per neighbourhood using a Plotly express `scatter_mapbox` visualization.

# %%
# Create a scatter mapbox to analyze neighbourhood info
map_avg_values = px.scatter_mapbox(
    df_joint,
    lat="lat",
    lon="lon",
    color="average_house_value",
    size="average_house_value",
    color_continuous_scale=px.colors.sequential.Jet,
    zoom = 10,
    mapbox_style="open-street-map",
    height=500,
    title="Average House Values in Toronto"
)
map_avg_values.show()

# %% [markdown]
# - - -

# %% [markdown]
# ## Cost Analysis - Optional Challenge
#
# In this section, you will use Plotly express to a couple of plots that investors can interactively filter and explore various factors related to the house value of the Toronto's neighbourhoods.
#
# ### Create a bar chart row facet to plot the average house values for all Toronto's neighbourhoods per year

# %%
# Getting average house values for all Toronto's neigbourhoods per year
df_avg_house_value_per_year = df_house_values.set_index("year")
df_avg_house_value_per_year.rename(columns={"average_house_value":"Avg. House Value"},inplace=True)
df_avg_house_value_per_year.head()
# Out:
#                      neighbourhood  Avg. House Value
# year
# 2001               Agincourt North            200388
# 2001  Agincourt South-Malvern West            203047
# 2001                     Alderwood            259998
# 2001                         Annex            453850
# 2001             Banbury-Don Mills            371864

# %%
# Create the bar chart row facet
bar_chart_cost_analysis = px.bar(
    df_avg_house_value_per_year,
    x='neighbourhood',
    y='Avg. House Value',
    facet_row=df_avg_house_value_per_year.index,
    title='Average House Values in Toronto per Neighbourhood',
    height=1000, 
    width=900, 
    hover_data=['Avg. House Value'], 
    color='Avg. House Value'
)
bar_chart_cost_analysis

# %% [markdown]
# ### Create a sunburst chart to conduct a costs analysis of most expensive neighbourhoods in Toronto per year

# %%
# Fetch the data for all neighbourhoods per year.
df_avg_cost_per_year = to_data[["neighbourhood","shelter_costs_owned", 'shelter_costs_rented']].reset_index()
df_avg_cost_per_year.head()
# Out:
#    year                 neighbourhood  shelter_costs_owned  \
# 0  2001               Agincourt North                  810
# 1  2001  Agincourt South-Malvern West                  806
# 2  2001                     Alderwood                  817
# 3  2001                         Annex                 1027
# 4  2001             Banbury-Don Mills                 1007
#
#    shelter_costs_rented
# 0                   870
# 1                   892
# 2                   924
# 3                  1378
# 4                  1163

# %%
# Fetch the list of most expensive neighbourhoods
list_expensive_

# %%
# Create the sunburst chart
sunburst_chart_cost_analysis =px.sunburst(
    df_avg_cost_per_year,
    path=['year', 'neighbourhood'], 
    values='shelter_costs_owned',
    color='shelter_costs_owned', 
    hover_data=['shelter_costs_rented'],
    color_continuous_scale=['red', 'yellow', 'green']
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-813687c9e947> in <module>
#       6     color='shelter_costs_owned',
#       7     hover_data=['shelter_costs_rented'],
# ----> 8     color_continuous_scale=['red', 'yellow', 'green']
#       9 )
#
# ~\anaconda3\envs\pyvizenv2\lib\site-packages\plotly\express\_chart_types.py in sunburst(data_frame, names, values, parents, path, ids, color, color_continuous_scale, range_color, color_continuous_midpoint, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, template, width, height, branchvalues, maxdepth)
#    1425         constructor=go.Sunburst,
#    1426         trace_patch=dict(branchvalues=branchvalues, maxdepth=maxdepth),
# -> 1427         layout_patch=layout_patch,
#    1428     )
#    1429
#
# ...
